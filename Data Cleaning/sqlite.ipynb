# %%
import pandas as pd
import sqlite3
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Project 4 MN Home-loan Predictive Model (HMDA Data-source)/\
Clean_Data_For_Model/Cleaned_loan_data_for_model.csv')

# %%
conn = sqlite3.connect('loan_data.db')
df.to_sql('loan_data', conn, if_exists='replace', index=False)

query = ('SELECT * FROM loan_data')

df = pd.read_sql(query, conn)

df
# Out:
#        activity_year                   lei state_code       county_name  \
# 0               2023  254900FKD0CVFUC78457         MN      Anoka County
# 1               2023  254900FKD0CVFUC78457         MN  St. Louis County
# 2               2023  254900FKD0CVFUC78457         MN  St. Louis County
# 3               2023  254900FKD0CVFUC78457         MN  St. Louis County
# 4               2023  254900FKD0CVFUC78457         MN  St. Louis County
# ...              ...                   ...        ...               ...
# 78263           2023  2549004FXPNKCLIN8250         MN     Ramsey County
# 78264           2023  254900EZRN0CBEP77K34         MN   Hennepin County
# 78265           2023  254900EZRN0CBEP77K34         MN     Ramsey County
# 78266           2023  254900EZRN0CBEP77K34         MN   Hennepin County
# 78267           2023  549300YCCZTMBHGTNQ79         MN    Douglas County
#
#       conforming_loan_limit             derived_dwelling_category  \
# ...
